# %% [markdown]
# # Pandas Fundamentals

# %% [markdown]
# **Pandas** provides fast, flexible, and expressive data structures designed to make working with “relational” or “labeled” data both easy and intuitive. It is built on top of **NumPy**, which is built on top of **C**. So, it is really fast.
#
# - **We highly recommend** that you go through the official Pandas' [Getting started tutorials](https://pandas.pydata.org/docs/getting_started/intro_tutorials/index.html).
# - Cheat Sheet: https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf
# - There is also this Kaggle course on Pandas: https://www.kaggle.com/learn/pandas
# - A mind map for Pandas' Methods: https://xmind.ai/share/ugVH30g4
#
# **Pandas Tutorial Notebooks**:
#
# - [Tutorial: Words Per Minute (01_wpm.ipynb)](../scenario/01_wpm.ipynb) (~30 min)
# - [Tutorial: Census (02_census.ipynb)](../scenario/02_census.ipynb) (~40 min)
# - [Exercise: Automobile Dataset](../exercises/ex_01_pandas_automobile/automobile_exercise.ipynb) (~30 min)

# %%
import pandas as pd
